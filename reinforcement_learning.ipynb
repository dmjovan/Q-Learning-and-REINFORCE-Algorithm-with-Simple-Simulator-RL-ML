# %% [markdown]
# # ----------------------------- Mašinsko učenje, Domaći zadatak 5 -----------------------------
# # -------------------------------- Jovan Dmitrović, 2021/3096 ----------------------------------

# %% [markdown]
# # Učitavanje biblioteka za rad

# %%
from qlearning import QLearningAgent
from reinforce import ReinforceAgent

# %% [markdown]
# # Treniranje Q-Learning agenta

# %% [markdown]
# ## Agent sa faktorom umanjenja buducih nagrada $\gamma$=0.9 i sa promenljivom stopom ucenja

# %%
agent = QLearningAgent(gamma=0.9)
agent.train()
agent.evaluate()
# Out:
# ------------------------ TRENIRANJE AGENTA ------------------------
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# ------------------------ EVALUACIJA AGENTA ------------------------
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Prosecna ukupna epizodna nagrada je: 3.0

# %% [markdown]
# ## Agent sa faktorom umanjenja buducih nagrada $\gamma$=0.9 i sa konstantnom stopom ucenja

# %%
del agent
agent = QLearningAgent(gamma=0.9, alpha=0.1)
agent.train()
agent.evaluate()
# Out:
# ------------------------ TRENIRANJE AGENTA ------------------------
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# ------------------------ EVALUACIJA AGENTA ------------------------
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Prosecna ukupna epizodna nagrada je: 3.0

# %% [markdown]
# ## Agent sa faktorom umanjenja buducih nagrada $\gamma$=0.999 i sa promenljivom stopom ucenja

# %%
del agent
agent = QLearningAgent(gamma=0.999)
agent.train()
agent.evaluate()
# Out:
# ------------------------ TRENIRANJE AGENTA ------------------------
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# ------------------------ EVALUACIJA AGENTA ------------------------
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Prosecna ukupna epizodna nagrada je: 3.0

# %% [markdown]
# ## Agent sa faktorom umanjenja buducih nagrada $\gamma$=0.999 i sa konstantnom stopom ucenja

# %%
del agent
agent = QLearningAgent(gamma=0.999, alpha=0.1)
agent.train()
agent.evaluate()
# Out:
# ------------------------ TRENIRANJE AGENTA ------------------------
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B1 :(
# Pufff! Agent je zavrsio epizodu u stanju B3 :(
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# ------------------------ EVALUACIJA AGENTA ------------------------
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Bravo! Agent je zavrsio epizodu u stanju B5 :)
# Prosecna ukupna epizodna nagrada je: 3.0

# %% [markdown]
# # Treniranje REINFORCE agenta

# %% [markdown]
# ## Agent sa promenljivom stopom ucenja

# %%
del agent
agent = ReinforceAgent()
agent.do_all()
# Out:
# Stanje A1 ------> Akcija RIGHT
# Stanje A2 ------> Akcija RIGHT
# Stanje A3 ------> Akcija RIGHT
# Stanje A4 ------> Akcija RIGHT
# Stanje A5 ------> Akcija UP
# Prosecna ukupna nagrada u toku jedne epizode je 0.6
# Stanje A1 ------> Akcija RIGHT
# Stanje A2 ------> Akcija RIGHT
# Stanje A3 ------> Akcija RIGHT
# Stanje A4 ------> Akcija RIGHT
# Stanje A5 ------> Akcija UP
# Prosecna ukupna nagrada u toku jedne epizode je 2.2
# Stanje A1 ------> Akcija RIGHT
# Stanje A2 ------> Akcija RIGHT
# Stanje A3 ------> Akcija RIGHT
# Stanje A4 ------> Akcija RIGHT
# Stanje A5 ------> Akcija UP
# Prosecna ukupna nagrada u toku jedne epizode je 1.8
# Stanje A1 ------> Akcija RIGHT
# Stanje A2 ------> Akcija RIGHT
# Stanje A3 ------> Akcija RIGHT
# Stanje A4 ------> Akcija RIGHT
# Stanje A5 ------> Akcija UP
# Prosecna ukupna nagrada u toku jedne epizode je 0.2

# %% [markdown]
# ## Agent sa konstantnom stopom ucenja 0.1

# %%
del agent
agent = ReinforceAgent(alpha=0.1)
agent.do_all()
# Out:
# Stanje A1 ------> Akcija DOWN
# Stanje A2 ------> Akcija RIGHT
# Stanje A3 ------> Akcija DOWN
# Stanje A4 ------> Akcija RIGHT
# Stanje A5 ------> Akcija DOWN
# Prosecna ukupna nagrada u toku jedne epizode je -0.6
# Stanje A1 ------> Akcija RIGHT
# Stanje A2 ------> Akcija RIGHT
# Stanje A3 ------> Akcija RIGHT
# Stanje A4 ------> Akcija RIGHT
# Stanje A5 ------> Akcija UP
# Prosecna ukupna nagrada u toku jedne epizode je 1.0
# Stanje A1 ------> Akcija RIGHT
# Stanje A2 ------> Akcija RIGHT
# Stanje A3 ------> Akcija RIGHT
# Stanje A4 ------> Akcija RIGHT
# Stanje A5 ------> Akcija UP
# Prosecna ukupna nagrada u toku jedne epizode je 1.4
# Stanje A1 ------> Akcija RIGHT
# Stanje A2 ------> Akcija RIGHT
# Stanje A3 ------> Akcija RIGHT
# Stanje A4 ------> Akcija RIGHT
# Stanje A5 ------> Akcija UP
# Prosecna ukupna nagrada u toku jedne epizode je 1.4
